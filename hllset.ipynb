# %%
from src.hllset_swarm.hll import HLL

hll_0 = HLL()
hll_1 = HLL()
hll_2 = HLL()

print(f"init hll_1 count: {hll_1.count()}")

print(hll_0.isequal(hll_1))

print(f"Julia HLLSet initialized with P={hll_0.P}", hll_0.count())
print(hll_0.isempty())
print(f"Hash : {hll_0.add(["masha", "dima","masha1", "dima1","masha2", "dima2"])}")
print(hll_0.count())

print(f"Hash : {hll_1.add(["masha", "dima","masha1", "dima1","masha2", "dima2"])}")
print(f"hll_1 count: {hll_1.count()}")

print(hll_0.isequal(hll_1))

print(f"Hash : {hll_2.add(["masha", "dima","masha1", "dima1","masha2", "dima2"], seed=13)[0].token}")
print(f"hll_2 count: {hll_2.count()}")

print(f"hll_1 = hll_2: {hll_1.isequal(hll_2)}")

print(f"intersection(hll_1, hll_2): {(hll_1.intersect(hll_2)).count()}")

# ===========================================================================

print(hll_0.cosine(hll_1))

print(hll_0.isequal(hll_1))


print(hll_0.isequal(hll_2))
# Out:
# init hll_1 count: 0.0
# 1.0
# Julia HLLSet initialized with P=10 0.0
# 1.0
# Hash : [AddResult(token='masha', hash_value=490790341354172971, register=55, leading_zeros=1), AddResult(token='dima', hash_value=8575861150253709111, register=953, leading_zeros=1), AddResult(token='masha1', hash_value=8479029121856555243, register=942, leading_zeros=1), AddResult(token='dima1', hash_value=6785219193404147217, register=754, leading_zeros=1), AddResult(token='masha2', hash_value=8971116065628070472, register=996, leading_zeros=4), AddResult(token='dima2', hash_value=6771139707086091806, register=752, leading_zeros=2)]
# 5.0
# ...
